# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('tips')
sns.catplot(x='day', y='total_bill', data=df)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_theme('talk')
sns.relplot(data=penguins,x='flipper_length_mm', y='bill_length_mm', col='island',hue='sex',style='species',) #kind='line'
#g.set_xticklabels(rotation=90)

# %%
sns.set_theme(style='whitegrid')
random_state = np.random.RandomState(365)
values = random_state.randn(365, 4).cumsum(axis=0)
dates = pd.date_range('2023-01-01', periods=365, freq='D')
df = pd.DataFrame(values, dates, columns=['A', 'B', 'C', 'D'])
df = df.rolling(7).mean()

# %%
df.fillna(1)
# Out:
#                     A          B          C          D
# 2023-01-01   1.000000   1.000000   1.000000   1.000000
# 2023-01-02   1.000000   1.000000   1.000000   1.000000
# 2023-01-03   1.000000   1.000000   1.000000   1.000000
# 2023-01-04   1.000000   1.000000   1.000000   1.000000
# 2023-01-05   1.000000   1.000000   1.000000   1.000000
# ...               ...        ...        ...        ...
# 2023-12-27 -18.482826  10.330142 -12.108625  14.878444
# 2023-12-28 -18.693797  10.391382 -12.020502  15.376387
# 2023-12-29 -18.752957  10.062616 -11.685921  15.996722
# 2023-12-30 -18.918042   9.957435 -11.244617  16.669990
# 2023-12-31 -19.239433  10.189316 -10.733219  17.307552
#
# [365 rows x 4 columns]

# %%
sns.set(rc={'figure.figsize':(15.37, 12.8)})
sns.lineplot(data=df, palette='tab10', linewidth=3.5)
# Out:
# <Axes: >
